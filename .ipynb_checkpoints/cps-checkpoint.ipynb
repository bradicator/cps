# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
class CPSAnalyzer:
    schools_of_interest = ["SKINNER", "SKINNER NORTH", "PRESCOTT", 'BRONZEVILLE CLASSICAL',
                          "HEALY", "LINCOLN", "PRITZKER", "BELL", "MAYER", "MCDADE"]
    def __init__(self):
        filename = "./iar-parcc_2015to2023_schoollevel.xlsx"
        self.dfenglish = pd.read_excel(filename, sheet_name=1, header=[0, 1])
        self.dfmath = pd.read_excel(filename, sheet_name=2, header=[0, 1])
        self.dfenglish = self.dfenglish.iloc[:, :12]
        self.dfmath = self.dfmath.iloc[:, :12]
        self.dfenglish.columns = self.dfenglish.columns.droplevel()
        self.dfmath.columns = self.dfmath.columns.droplevel()

    def rank_schools(self):
        mathdf = self.dfmath.loc[self.dfmath['Year']==2023, :]
        self.ranked_math = mathdf.groupby("School Name")["% Met or Exceeded"].mean().sort_values(ascending = False).index.values
        self.ranked_math_exceed = mathdf.groupby("School Name")["% Exceeded"].mean().sort_values(ascending = False).index.values
        engdf = self.dfenglish.loc[self.dfenglish['Year']==2023, :]
        self.ranked_english = engdf.groupby("School Name")["% Met or Exceeded"].mean().sort_values(ascending = False).index.values
        self.ranked_english_exceed = engdf.groupby("School Name")["% Exceeded"].mean().sort_values(ascending = False).index.values
        return self.ranked_math, self.ranked_english

    def infer_skinner(self, control, subject="math", only_exceed=1, nselect=30):
        if only_exceed:
            valuename = "% Exceeded"
        else:
            valuename = "% Met or Exceeded"

        if subject == "math":
            test_of_interest = ["Mathematics Grade " + str(i) for i in range(3,9)]
            dfc = self.dfmath.loc[(self.dfmath['School Name'] == control) & (self.dfmath['Test Name'].isin(test_of_interest)), :]
            df = self.dfmath.loc[(self.dfmath['School Name'] == "SKINNER") & (self.dfmath['Test Name'].isin(test_of_interest)), :]
        else:
            test_of_interest = ["ELA/Literacy Grade " + str(i) for i in range(3,9)]
            dfc = self.dfenglish.loc[(self.dfenglish['School Name'] == control) & (self.dfenglish['Test Name'].isin(test_of_interest)), :]
            df = self.dfenglish.loc[(self.dfenglish['School Name'] == "SKINNER") & (self.dfenglish['Test Name'].isin(test_of_interest)), :]
        
        for idx, r in df.iterrows():
            n = r["# Students Tested"]
            control_prop = dfc.loc[(dfc.Year==r["Year"]) & (dfc["Test Name"]==r["Test Name"]), valuename]
            val = (n * r[valuename] - (n-nselect) * control_prop) / nselect
            df.loc[idx, valuename] = int(val.values)
        dfp = df.pivot(columns='Year', index='Test Name', values=valuename)
        return dfp, df, dfc
        
    def nstudent(self, school):
        test_of_interest = ["Mathematics Grade " + str(i) for i in range(3,9)]
        df = self.dfmath.loc[(self.dfmath['School Name'] == school) & (self.dfmath['Test Name'].isin(test_of_interest)), :]
        dfp = df.pivot(columns='Year', index='Test Name', values='# Students Tested')
        dfp.index = [int(s[-1]) for s in dfp.index]
        dfp.index.name = 'Grade'
        dfp.sort_index(ascending=False, inplace=True)
        dfp.columns = dfp.columns.astype(str)
        try:
            dfp.loc[:, "2020"] = np.nan
            for i in range(3,7):
                dfp.loc[i+1, "2020"] = 0.5 * (dfp.loc[i, "2019"] + dfp.loc[i+2, "2021"])
        except:
            pass
        dfp.sort_index(axis=1, inplace=True)
        return dfp
    
    def heatmap(self, school, subject="math", only_exceed=1, threshold=0):
        if only_exceed:
            valuename = "% Exceeded"
        else:
            valuename = "% Met or Exceeded"
            
        if subject == "math":
            test_of_interest = ["Mathematics Grade " + str(i) for i in range(3,9)]
            df = self.dfmath.loc[(self.dfmath['School Name'] == school) & (self.dfmath['Test Name'].isin(test_of_interest)), :]
        else:
            test_of_interest = ["ELA/Literacy Grade " + str(i) for i in range(3,9)]
            df = self.dfenglish.loc[(self.dfenglish['School Name'] == school) & (self.dfenglish['Test Name'].isin(test_of_interest)), :]
        
        if df.empty:
            print("empty data")
            return False

        nstudent = df['# Students Tested'].mean()
        dfp = df.pivot(columns='Year', index='Test Name', values=valuename)
        avg2023 = dfp.iloc[:, -1].mean()
        if avg2023 < threshold:
            return False
        dfp.index = [int(s[-1]) for s in dfp.index]
        dfp.index.name = 'Grade'
        dfp.sort_index(ascending=False, inplace=True)
        dfp.columns = dfp.columns.astype(str)
        try:
            dfp.loc[:, "2020"] = np.nan
            for i in range(3,7):
                dfp.loc[i+1, "2020"] = 0.5 * (dfp.loc[i, "2019"] + dfp.loc[i+2, "2021"])
        except:
            pass
        
        dfp.sort_index(axis=1, inplace=True)
        fig, ax = plt.subplots(1, 1, figsize=(8, 6))
        ax.set_title(f"{school} {subject} avg: {int(avg2023)} N: {int(nstudent)}")
        sns.heatmap(dfp, cbar=None, cmap=sns.light_palette('green', as_cmap=True), vmin=0, vmax=100, annot=dfp,
                   square=False,ax=ax, annot_kws={'color':'black', 'size':14}, fmt='.0f')
        ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
        ax.set_ylabel("grade", rotation=0, labelpad=10)
        ax.set_xlabel("year")

        row_mean = dfp.mean(axis=1)
        col_mean = dfp.mean(axis=0)
        row_mean = row_mean.fillna(-1)
        col_mean = col_mean.fillna(-1)
        
        ax_right = ax.twinx()
        ax_right.set_ylim(ax.get_ylim())
        new_labels = [str(int(i)) for i in row_mean]
        ax_right.set_yticks(ax.get_yticks())
        ax_right.set_yticklabels(new_labels)
        ax_right.set_ylabel("row mean", rotation=0, labelpad=10)

        ax_top = ax.twiny()
        ax_top.set_xlim(ax.get_xlim())
        new_labels = [str(int(i)) for i in col_mean]
        ax_top.set_xticks(ax.get_xticks())
        ax_top.set_xticklabels(new_labels)
        ax_top.set_xlabel("column mean")
        return fig, ax, dfp

# %%
class CPSAnalyzer:
    schools_of_interest = ["SKINNER", "SKINNER NORTH", "PRESCOTT", 'BRONZEVILLE CLASSICAL',
                          "HEALY", "LINCOLN", "PRITZKER", "BELL", "MAYER", "MCDADE"]
    def __init__(self):
        filename = "./iar-parcc_2015to2023_schoollevel.xlsx"
        self.dfenglish = pd.read_excel(filename, sheet_name=1, header=[0, 1])
        self.dfmath = pd.read_excel(filename, sheet_name=2, header=[0, 1])
        self.dfenglish = self.dfenglish.iloc[:, :12]
        self.dfmath = self.dfmath.iloc[:, :12]
        self.dfenglish.columns = self.dfenglish.columns.droplevel()
        self.dfmath.columns = self.dfmath.columns.droplevel()

    def rank_schools(self):
        mathdf = self.dfmath.loc[self.dfmath['Year']==2023, :]
        self.ranked_math = mathdf.groupby("School Name")["% Met or Exceeded"].mean().sort_values(ascending = False).index.values
        self.ranked_math_exceed = mathdf.groupby("School Name")["% Exceeded"].mean().sort_values(ascending = False).index.values
        engdf = self.dfenglish.loc[self.dfenglish['Year']==2023, :]
        self.ranked_english = engdf.groupby("School Name")["% Met or Exceeded"].mean().sort_values(ascending = False).index.values
        self.ranked_english_exceed = engdf.groupby("School Name")["% Exceeded"].mean().sort_values(ascending = False).index.values
        return self.ranked_math, self.ranked_english

    def infer_skinner(self, control, subject="math", only_exceed=1, nselect=30):
        if only_exceed:
            valuename = "% Exceeded"
        else:
            valuename = "% Met or Exceeded"

        if subject == "math":
            test_of_interest = ["Mathematics Grade " + str(i) for i in range(3,9)]
            dfc = self.dfmath.loc[(self.dfmath['School Name'] == control) & (self.dfmath['Test Name'].isin(test_of_interest)), :]
            df = self.dfmath.loc[(self.dfmath['School Name'] == "SKINNER") & (self.dfmath['Test Name'].isin(test_of_interest)), :]
        else:
            test_of_interest = ["ELA/Literacy Grade " + str(i) for i in range(3,9)]
            dfc = self.dfenglish.loc[(self.dfenglish['School Name'] == control) & (self.dfenglish['Test Name'].isin(test_of_interest)), :]
            df = self.dfenglish.loc[(self.dfenglish['School Name'] == "SKINNER") & (self.dfenglish['Test Name'].isin(test_of_interest)), :]
        
        for idx, r in df.iterrows():
            n = r["# Students Tested"]
            control_prop = dfc.loc[(dfc.Year==r["Year"]) & (dfc["Test Name"]==r["Test Name"]), valuename]
            val = (n * r[valuename] - (n-nselect) * control_prop) / nselect
            df.loc[idx, valuename] = int(val.values)
        dfp = df.pivot(columns='Year', index='Test Name', values=valuename)
        return CPSAnalyzer.plot_heatmap(dfp, title="inferred for skinner")
        
    def nstudent(self, school):
        test_of_interest = ["Mathematics Grade " + str(i) for i in range(3,9)]
        df = self.dfmath.loc[(self.dfmath['School Name'] == school) & (self.dfmath['Test Name'].isin(test_of_interest)), :]
        dfp = df.pivot(columns='Year', index='Test Name', values='# Students Tested')
        dfp.index = [int(s[-1]) for s in dfp.index]
        dfp.index.name = 'Grade'
        dfp.sort_index(ascending=False, inplace=True)
        dfp.columns = dfp.columns.astype(str)
        return CPSAnalyzer.plot_heatmap(dfp, title="number of students")

    @staticmethod
    def plot_heatmap(dfp, infer_2020=True, title=""):
        if infer_2020:
            try:
                dfp.loc[:, "2020"] = np.nan
                for i in range(3,7):
                    dfp.loc[i+1, "2020"] = 0.5 * (dfp.loc[i, "2019"] + dfp.loc[i+2, "2021"])
            except:
                pass
            dfp.sort_index(axis=1, inplace=True)
        fig, ax = plt.subplots(1, 1, figsize=(8, 6))
        ax.set_title(title)
        sns.heatmap(dfp, cbar=None, cmap=sns.light_palette('green', as_cmap=True), vmin=0, vmax=100, annot=dfp,
                   square=False,ax=ax, annot_kws={'color':'black', 'size':14}, fmt='.0f')
        ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
        ax.set_ylabel("grade", rotation=0, labelpad=10)
        ax.set_xlabel("year")

        row_mean = dfp.mean(axis=1)
        col_mean = dfp.mean(axis=0)
        row_mean = row_mean.fillna(-1)
        col_mean = col_mean.fillna(-1)
        
        ax_right = ax.twinx()
        ax_right.set_ylim(ax.get_ylim())
        new_labels = [str(int(i)) for i in row_mean]
        ax_right.set_yticks(ax.get_yticks())
        ax_right.set_yticklabels(new_labels)
        ax_right.set_ylabel("row mean", rotation=0, labelpad=10)

        ax_top = ax.twiny()
        ax_top.set_xlim(ax.get_xlim())
        new_labels = [str(int(i)) for i in col_mean]
        ax_top.set_xticks(ax.get_xticks())
        ax_top.set_xticklabels(new_labels)
        ax_top.set_xlabel("column mean")
        return fig, ax, dfp
        
    def heatmap(self, school, subject="math", only_exceed=1, threshold=0):
        if only_exceed:
            valuename = "% Exceeded"
        else:
            valuename = "% Met or Exceeded"
            
        if subject == "math":
            test_of_interest = ["Mathematics Grade " + str(i) for i in range(3,9)]
            df = self.dfmath.loc[(self.dfmath['School Name'] == school) & (self.dfmath['Test Name'].isin(test_of_interest)), :]
        else:
            test_of_interest = ["ELA/Literacy Grade " + str(i) for i in range(3,9)]
            df = self.dfenglish.loc[(self.dfenglish['School Name'] == school) & (self.dfenglish['Test Name'].isin(test_of_interest)), :]
        
        if df.empty:
            print("empty data")
            return False

        nstudent = df['# Students Tested'].mean()
        dfp = df.pivot(columns='Year', index='Test Name', values=valuename)
        avg2023 = dfp.iloc[:, -1].mean()
        if avg2023 < threshold:
            return False
        dfp.index = [int(s[-1]) for s in dfp.index]
        dfp.index.name = 'Grade'
        dfp.sort_index(ascending=False, inplace=True)
        dfp.columns = dfp.columns.astype(str)
        title = f"{school} {subject} avg: {int(avg2023)} N: {int(nstudent)}"
        return CPSAnalyzer.plot_heatmap(dfp, title=title)

# %%
cps = CPSAnalyzer()

# %%
cps.nstudent("SKINNER")
# Out:
# (<Figure size 800x600 with 3 Axes>,
#  <Axes: title={'center': 'number of students'}, xlabel='year', ylabel='grade'>,
#  Year    2015   2016   2017   2018   2019   2020   2021   2022   2023
#  Grade
#  8       45.0    NaN   65.0   61.0   81.0    NaN   47.0   88.0   77.0
#  7       49.0   65.0   67.0   76.0   93.0   85.5   89.0   78.0   86.0
#  6       82.0   91.0  103.0  120.0  124.0  121.0  108.0  118.0   97.0
#  5       90.0  100.0  127.0  122.0  153.0  116.0  108.0  102.0  102.0
#  4      100.0  128.0  120.0  149.0  124.0  122.5   96.0  103.0  138.0
#  3      129.0  123.0  144.0  125.0  137.0    NaN  104.0  139.0   97.0)

# %%
dfp, df, dfc = cps.infer_skinner("LINCOLN")
# Out:
# /var/folders/q9/lwq6t7zx19lgn4638rq3kwg80000gn/T/ipykernel_27409/1500049924.py:41: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   df
# 22738              3.1           8.6   43.1        44.6               87.7
# 23354              3.1          12.5   42.2        40.6               82.8
# 25176              4.1           4.1   49.0        42.9               91.8
# 24270              4.4          11.1   45.6        37.8               83.3
# 24726              0.0           1.2   41.5        57.3               98.8
# 23814              5.3          12.6   43.2        38.9               82.1
# 22078              3.9           2.0   27.5        66.7               94.1
# 21630              3.1           0.0   23.1        73.8               96.9
# 21179              3.3          15.4   35.2        44.0               79.1
# 20723              7.1          15.2   50.5        22.2               72.7
# 20264              5.6          16.7   44.4        32.5               77.0
# 19804              9.0           6.6   45.9        36.1               82.0
# 19177              5.8          10.6   40.3        41.3               81.6
# 15968              5.8          14.7   41.4        35.9               77.3
# 16436              2.8          14.0   46.2        33.6               79.7
# 16893              7.6          10.9   43.7        37.0               80.7
# 17798             11.1          18.2   28.3        40.4               68.7
# 18243              4.5          22.4   37.3        31.3               68.7
# 17347              5.5          17.2   46.1        28.9               75.0
# 18685              3.1           4.6   41.5        50.8               92.3
# 12780              4.7          14.6   47.1        30.5               77.6
# 15485              6.3          15.9   41.3        28.6               69.8
# 15046              3.9          14.3   40.3        32.5               72.7
# 14603              2.7          20.4   43.4        33.6               77.0
# 14155              5.0           5.8   61.7        25.0               86.7
# 13701              6.8          18.5   37.0        37.0               74.0
# 13244              3.2          12.9   55.6        25.0               80.6
# 12296              8.5          18.3   53.7        14.6               68.3
# 11404              7.9          14.2   54.3        22.8               77.2
# 10951              5.7          14.6   52.9        24.2               77.1
# 10495              4.8          19.4   45.2        24.2               69.4
# 10036              5.1           7.2   44.2        39.9               84.1
# 9571               6.0          14.7   48.9        26.7               75.6
# 11848              4.3          17.0   42.6        30.9               73.4
# 9106               5.8          17.3   51.9        15.4               67.3
# 8732              12.8          14.9   38.3        25.5               63.8
# 8354              11.6          16.1   53.6        13.4               67.0
# 7968               6.3          25.2   55.9         7.2               63.1
# 7586              10.5          16.8   41.1        27.4               68.4
# 7192               7.5          17.0   56.6        16.0               72.6
# 6781               9.3          18.1   49.8        17.2               67.0
# 3577               9.2          13.7   50.5        17.7               68.2
# 4042               7.2          17.3   51.8        15.8               67.6
# 4496               6.7          12.4   48.6        22.9               71.4
# 5856              13.8          13.8   35.0        26.3               61.3
# 5404               8.1          13.7   53.2        15.3               68.5
# 6304              13.8          11.7   53.2         9.6               62.8
# 4950               7.8          11.8   56.9        18.6               75.5
# 3097              13.0          19.5   46.8         7.8               54.5
# 2645              10.5          14.0   38.4        22.1               60.5
# 2194               5.2           8.2   56.7        24.7               81.4
# 1741               6.9          14.7   52.9        19.6               72.5
# 1286               8.7          15.9   34.1        31.2               65.2
# 829               14.4          29.9   42.3         2.1               44.3
# 364                9.5          16.9   44.6        19.1               63.7

# %%
np.round(2.9777799, 0)
# Out:
# 3.0

# %%
nselect = 30
for idx, r in df.iterrows():
    n = r["# Students Tested"]
    control_prop = dfc.loc[(dfc.Year==r["Year"]) & (dfc["Test Name"]==r["Test Name"]), "% Exceeded"]
    val = (n * r["% Exceeded"] - (n-nselect) * control_prop) / nselect
    df.loc[idx, "% Exceeded"] = int(val.values)
df.head()
# Out:
#       School ID School Name  Year            Test Name  # Students Tested  \
# 829      610177     SKINNER  2023  Mathematics Grade 3                 97
# 1286     610177     SKINNER  2023  Mathematics Grade 4                138
# 1741     610177     SKINNER  2023  Mathematics Grade 5                102
# 2194     610177     SKINNER  2023  Mathematics Grade 6                 97
# 2645     610177     SKINNER  2023  Mathematics Grade 7                 86
#
#      Overall Math Mean Scale Score  % Did Not Meet  % Partially Met  \
# 829                            768             8.2             10.3
# 1286                           767             9.4             10.1
# 1741                           770             7.8             11.8
# 2194                           767             6.2              8.2
# 2645                           752            12.8             17.4
#
#       % Approached  % Met  % Exceeded  % Met or Exceeded
# 829           15.5   30.9   60.560000               66.0
# 1286          13.0   40.6   33.280000               67.4
# 1741          15.7   27.5   97.540000               64.7
# 2194          17.5   32.0   83.893333               68.0
# 2645          14.0   33.7   31.806667               55.8

# %%
df.head()
# Out:
#       School ID School Name  Year            Test Name  # Students Tested  \
# 829      610177     SKINNER  2023  Mathematics Grade 3                 97
# 1286     610177     SKINNER  2023  Mathematics Grade 4                138
# 1741     610177     SKINNER  2023  Mathematics Grade 5                102
# 2194     610177     SKINNER  2023  Mathematics Grade 6                 97
# 2645     610177     SKINNER  2023  Mathematics Grade 7                 86
#
#      Overall Math Mean Scale Score  % Did Not Meet  % Partially Met  \
# 829                            768             8.2             10.3
# 1286                           767             9.4             10.1
# 1741                           770             7.8             11.8
# 2194                           767             6.2              8.2
# 2645                           752            12.8             17.4
#
#       % Approached  % Met  % Exceeded  % Met or Exceeded
# 829           15.5   30.9        35.1               66.0
# 1286          13.0   40.6        26.8               67.4
# 1741          15.7   27.5        37.3               64.7
# 2194          17.5   32.0        36.1               68.0
# 2645          14.0   33.7        22.1               55.8

# %%
fig, ax, dfp = cps.heatmap("YOUNG HS", "english", only_exceed=1)

# %%
_ = cps.rank_schools()

# %%
nplots = 50
with PdfPages('eng_exceed.pdf') as pdf:
    for s in cps.ranked_english_exceed[:nplots]:
        if cps.heatmap(s, "english", only_exceed=1):
            pdf.savefig()  
            plt.close()

# %%
nplots = 50
with PdfPages('eng_met_or_exceed.pdf') as pdf:
    for s in cps.ranked_english[:nplots]:
        if cps.heatmap(s, "english", only_exceed=0):
            pdf.savefig()  
            plt.close()

# %%
nplots = 50
with PdfPages('math_exceed.pdf') as pdf:
    for s in cps.ranked_math_exceed[:nplots]:
        if cps.heatmap(s, "math", only_exceed=1):
            pdf.savefig()  
            plt.close()

# %%
nplots = 50
with PdfPages('math_met_or_exceed.pdf') as pdf:
    for s in cps.ranked_math[:nplots]:
        if cps.heatmap(s, "math", only_exceed=0):
            pdf.savefig()  
            plt.close()
